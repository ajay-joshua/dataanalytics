# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2
from collections import Counter
from skimage.color import rgb2lab, deltaE_cie76
import os

# %%
# %matplotlib inline

# %%
from google.colab import drive
drive.mount("/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
import os
os.chdir("/gdrive/My Drive/")
os.listdir()
# Out:
# ['Untitled Folder',
#  'image1.jpeg',
#  'exam sylabuses - Copy.zip',
#  'Untitled',
#  'Untitled (1)',
#  'Untitled (2)',
#  'Untitled (3)',
#  'Untitled spreadsheet.gsheet',
#  'Untitled presentation.gslides',
#  'WIndows10 ReadMe.txt.gdoc',
#  'Economics Unit 3.gdoc',
#  'Untitled document.gdoc',
#  'Consulting agreement.gdoc',
#  'Intern report - Bar chart 1.gsheet',
#  'Intern report.gdoc',
#  'Website',
#  'Untitled spreadsheet (1).gsheet',
#  'Resume (1).gdoc',
#  'Resume.gdoc',
#  'Untitled document (2).gdoc',
#  'Pet resume.gdoc',
#  'Untitled document (1).gdoc',
#  'Colab Notebooks',
#  'Airline-Dataset.csv',
#  'vgsalesdataanalysis-Copy1.ipynb',
#  'CompleteDataset.csv',
#  'Bundesliga_Results.csv',
#  'One.ipynb',
#  'Classroom',
#  'tmdb_5000_movies.csv',
#  'Datafiniti_Pizza_Restaurants_and_the_Pizza_They_Sell_May19.csv',
#  'DM.zip',
#  'nn_with weights.ipynb',
#  'iris.csv',
#  'iris.data',
#  '16Z202 Data Anlytic Lab',
#  'Sem 7.rar',
# ...

# %%
image=cv2.imread('rose.jpg')

# %%
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#image in bgr mode-
plt.imshow(image)

# %%
#converting bgr to rgb
image1 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image1)

# %%
scaled_image = cv2.resize(image, (400, 400))
plt.imshow(scaled_image)

# %%
height, width = gray_image.shape[:2]
height
width
# Out:
# 400

# %%
#converting to grayscale

gray_image = cv2.cvtColor(scaled_image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')

# %%
 hsv = cv2.cvtColor(scaled_image, cv2.COLOR_BGR2HSV) 
plt.imshow(hsv)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F7BA1D034E0>

# %%
from google.colab.patches import cv2_imshow

# %%
coord=cv2.findNonZero(mask)

# %%
lower_red = np.array([0,50,50])
upper_red = np.array([10,255,255])
red_maskmajor = cv2.inRange(img_hsv, lower_red, upper_red)
cv2_imshow(red_maskmajor)
# Out:
# <PIL.Image.Image image mode=L size=458x458 at 0x7F7BA3A837F0>

# %%
lower_red = np.array([170,50,50])
upper_red = np.array([180,255,255])
red_maskminor = cv2.inRange(img_hsv, lower_red, upper_red)
cv2_imshow(red_maskminor)
# Out:
# <PIL.Image.Image image mode=L size=458x458 at 0x7F7BA3A837F0>

# %%
mask = red_maskmajor+red_maskminor
cv2_imshow(mask)
# Out:
# <PIL.Image.Image image mode=L size=458x458 at 0x7F7BA3932160>

# %%
output_img = image.copy()
output_img[np.where(mask==0)] = 0

# %%
cv2_imshow(output_img)
# Out:
# <PIL.Image.Image image mode=RGB size=458x458 at 0x7F7BA39329B0>
